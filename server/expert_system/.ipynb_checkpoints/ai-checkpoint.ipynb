# %%
import tensorflow as tf
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
df = pd.read_csv('prices.csv')
df.head()
# Out:
#    Dist Code  Year  State Code    State Name Dist Name  \
# 0          1  1990          14  Chhattisgarh      Durg
# 1          1  1991          14  Chhattisgarh      Durg
# 2          1  1992          14  Chhattisgarh      Durg
# 3          1  1993          14  Chhattisgarh      Durg
# 4          1  1994          14  Chhattisgarh      Durg
#
#    RICE HARVEST PRICE (Rs per Quintal)  PADDY HARVEST PRICE (Rs per Quintal)  \
# 0                                382.0                                 230.0
# 1                                453.0                                 221.0
# 2                                497.0                                  -1.0
# 3                                533.0                                 321.0
# 4                                580.0                                 349.0
#
#    WHEAT HARVEST PRICE (Rs per Quintal)  \
# 0                                 329.0
# 1                                 384.0
# 2                                 448.0
# 3                                 463.0
# 4                                 491.0
#
#    SORGHUM HARVEST PRICE (Rs per Quintal)  \
# 0                                    -1.0
# 1                                    -1.0
# 2                                    -1.0
# 3                                    -1.0
# 4                                    -1.0
#
#    PEARL MILLET HARVEST PRICE (Rs per Quintal)  ...  \
# 0                                         -1.0  ...
# 1                                         -1.0  ...
# 2                                         -1.0  ...
# 3                                         -1.0  ...
# 4                                         -1.0  ...
#
#    BARLEY HARVEST PRICE (Rs per Quintal)  \
# 0                                   -1.0
# 1                                   -1.0
# 2                                   -1.0
# 3                                   -1.0
# 4                                   -1.0
#
#    CHICKPEA HARVEST PRICE (Rs per Quintal)  \
# 0                                    602.0
# 1                                    641.0
# 2                                    728.0
# 3                                    986.0
# 4                                    842.0
#
#    PIGEONPEA HARVEST PRICE (Rs per Quintal)  \
# 0                                     858.0
# 1                                     822.0
# 2                                     992.0
# 3                                     908.0
# 4                                    1268.0
#
#    GROUNDNUT HARVEST PRICE (Rs per Quintal)  \
# 0                                      -1.0
# 1                                      -1.0
# 2                                      -1.0
# 3                                      -1.0
# 4                                      -1.0
#
#    SEASMUM HARVEST PRICE (Rs per Quintal)  \
# 0                                  1014.0
# 1                                  1750.0
# 2                                  1407.0
# 3                                  1325.0
# 4                                  2750.0
#
#    RAPE AND MUSTARD HARVEST PRICE (Rs per Quintal)  \
# 0                                             -1.0
# 1                                             -1.0
# 2                                             -1.0
# 3                                             -1.0
# 4                                             -1.0
#
#    CASTOR HARVEST PRICE (Rs per Quintal)  \
# 0                                   -1.0
# 1                                   -1.0
# 2                                   -1.0
# 3                                   -1.0
# 4                                   -1.0
#
#    LINSEED HARVEST PRICE (Rs per Quintal)  \
# 0                                   978.0
# 1                                  1053.0
# 2                                   903.0
# 3                                  1009.0
# 4                                  1134.0
#
#    SUGARCANE GUR HARVEST PRICE (Rs per Quintal)  \
# 0                                          -1.0
# 1                                          -1.0
# 2                                          -1.0
# 3                                          -1.0
# 4                                          -1.0
#
#    COTTON KAPAS HARVEST PRICE (Rs per Quintal)
# 0                                         -1.0
# 1                                         -1.0
# 2                                         -1.0
# 3                                         -1.0
# 4                                         -1.0
#
# [5 rows x 22 columns]

# %%
columns = ['city','crop']
columns.extend([str(i) for i in range(1990,2017)])
dtypes=numpy.dtype(list(map(lambda x: (x,float), columns)))
df2 = pd.DataFrame(numpy.empty(0,dtype=dtypes))
df2[['city','crop']]=df2[['city','crop']].astype(str)

# %%
crops=["RICE","PADDY","WHEAT","SORGHUM","PEARL MILLET","MAIZE","FINGER MILLET","BARLEY","CHICKPEA","PIGEONPEA","GROUNDNUT","SEASMUM","RAPE AND MUSTARD","CASTOR","LINSEED","SUGARCANE GUR","COTTON KAPAS"]
cities=set()
for index,data in df.iterrows():
    cities.add(data['Dist Name'])
print(len(cities))
# Out:
# 533

# %%
for city in cities:
    for crop in crops:
        df2=df2.append({'city':city, 'crop':crop}, ignore_index=True)

# %%
df2.head()
# Out:
#           city          crop  1990  1991  1992  1993  1994  1995  1996  1997  \
# 0  Rae-Bareily          RICE   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Rae-Bareily         PADDY   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  Rae-Bareily         WHEAT   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  Rae-Bareily       SORGHUM   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  Rae-Bareily  PEARL MILLET   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 29 columns]
